# %%
"""类的常见错误：
语法错误
self   实现类中实例的代替，以完成相应类中方法调用
cls    将方法定义为类的方法，实现类中方法的直接调用
设计错误
定义对象的错误 类 属性 方法
类之间的依赖

设计原则  SOLID原则
S 单一职责  只负责一件事（小 好）
O 开闭  扩展开放，修改关闭
L 里式替换    某个对象使用子类时，应当和使用父类有相同的行为  （能够无差别使用子类）
I 接口隔离原则   接口越小越好    “鸭子类型”    定义相关魔术方法，就可以像相关类型一样调用
D 依赖倒置原则  高层模块 不应该依赖低层模块  应该让二者依赖抽象（如第三方类）
"""
