# %%
"""
怎样合理组合多个函数和类
1创建型模式
2结构型模式
3行为模式
"""

# %%
"""
创建型模式
经典： 单例模式
单实例模式可以由import 来实现
可以借助类的属性实现多实例共享(monostate)一个属性
"""

# %%
"""
结构型模式
实用的是 适配模式，解决兼容问题

"""

# %%
"""
行为模式
责任链模式实现可发送者和接收者解耦，让多个对象接收发送者请求
，并沿着链式结构一直传递，直到有目标对象处理该请求为止
经典场景：异常的分层处理
"""
# Out:
# ''

# %%
"""
总结：
设计模式非常丰富，主要根据行为分为创建型、结构型、行为型
可以让程序应对更复杂的需求场景
设计模式有较为成熟的代码和解决方案，可以利用现有的代码缩短开发时间"""
