# %%
"""
为什么使用混合编程
1 Python是一种解释型语言，运行速度慢，不适合处理大量数据
2 C++是一种编译型语言，运行速度快，适合处理大量数据，开发效率低
3 使用Python和C++混合编程，可以提高开发效率和运行速度
"""

# %%
"""
实现混合编程的方式
1 ctypes库加载C++动态库     C
2 pybind 将C++编译为Python库   转换为中间语言
3 使用Pythran将Python编译为C++库  好用重点
  只需要注意函数逻辑，然后在C++中调用
"""

# %%
"""
Pythran转换代码
1 编写需要转换为C++的函数
2 使用Pythran命令行转换为C++代码
3 编写C++测试代码
"""
