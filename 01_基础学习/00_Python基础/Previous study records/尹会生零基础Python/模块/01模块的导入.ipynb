# %%
"""
模块的作用
模块是存放了函数 且以 .py结尾的文件
作用：
将函数放在模块文件中，隐藏代码细节，使主要逻辑清晰
"""

"""
导入模块的方法
import os                导入整个模块
from os import chdir     特定方法导入
"""

# %%
import os
os.getcwd()
# Out:
# 'F:\\develop\\Python\\Code\\project-01\\尹会生零基础Python\\模块'

# %%
from os import getcwd
getcwd()
# Out:
# 'F:\\develop\\Python\\Code\\project-01\\尹会生零基础Python\\模块'

# %%
"""
将多个模块放在一个文件夹中，该文件夹称作包
导入方式相同
为导入的模块指定名称
import numpy as np
不建议使用* 导入所有的函数
from os import*
"""

# %%
"""
总结：导入时，避免重名  使用 模块.函数名
"""
