# %%
import test66 as t
dir(t)
# Out:
# ['Class1',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'func1',
#  'var']

# %%
t.func1()
# Out:
# func1 is called

# %%
t.var
# Out:
# 100

# %%
obj =t.Class1()
# Out:
# Class1 is called

# %%
"""
注意事项
1 导入自定义模块时，确保路径正确
2 文件名称避免特殊字符，避免于标准库重名
3 模块多次导入，只会执行一次
4 自定义模块中应为函数定义，避免在模块中编写函数调用代码， 解决方法：或将调用代码放入__name__ 代码块中
"""
