# %%
"""
第三方模块的安装：
pip 命令
pip3.13 install 模块名
python3.10 -m pip install 模块名
"""

# %%
"""虚拟环境
用途
解决多个模块依赖问题
一次性安装多个指定版本的模块
避免对默认环境的污染
"""
"""
创建虚拟环境
python3.10 -m venv 虚拟环境名
venv  虚拟环境模块
虚拟环境名   保存虚拟环境的文件夹名
"""
# Out:
# ''
