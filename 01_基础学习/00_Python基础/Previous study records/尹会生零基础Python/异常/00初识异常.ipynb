# %%
"""
异常是解释器在执行代码时遇到，出现错误时的管理机制，会在错误被检测到的位置"引发"
引发异常时，代码块会发生中断
异常是一种 特殊对象
"""

# %%
"""
除了SystemExit异常外，当异常没有被完全处理时，都会打印栈回溯信息
"""
# Out:
# '\n除了SystemExit异常外，当异常没有被完全处理时，都会打印栈回溯信息\n'

# %%
"""
异常的分类：
- 内置异常的基类，树形结构：BaseException
- 自定义异常：Exception，所有内置的非系统的退出类异常派生自此类，由用户自定义异常也应当派生自此类
"""
