# %%
"""
PDF 是 Portable Document Format 的缩写，这类文件通常使用.pdf作为其扩展名。
"""
# Out:
# ''

# %%
"""
从PDF中提取文本
PyPDF2 没有办法从 PDF 文档中提取图像、图表或其他媒体，但它可以提取文本，并将其返回为 Python 字符串。

要从 PDF 文件中提取文本也可以直接使用三方的命令行工具，具体的做法如下所示。

pip install pdfminer.six
pdf2text.py test.pdf
"""
import PyPDF2

reader = PyPDF2.PdfReader('test.pdf')
for page in reader.pages:
    print(page.extract_text())
# Out:
# ''

# %%
"""
旋转和叠加页面
创建PdfFileReader对象的方式来读取 PDF 文档，该对象的getPage方法可以获得PDF文档的指定页并得到一个PageObject对象，通过
PageObject对象的rotateClockwise和rotateCounterClockwise方法可以实现页面的顺时针和逆时针方向旋转，通过PageObject
对象的addBlankPage方法可以添加一个新的空白页，代码如下所示。
"""
reader = PyPDF2.PdfReader('XGBoost.pdf')
writer = PyPDF2.PdfWriter()

for no, page in enumerate(reader.pages):
    if no % 2 == 0:
        new_page = page.rotate(-90)
    else:
        new_page = page.rotate(90)
    writer.add_page(new_page)

with open('temp.pdf', 'wb') as file_obj:
    writer.write(file_obj)

# %%
"""
加密PDF文件
使用PyPDF2中的PdfFileWrite对象可以为PDF文档加密，如果需要给一系列的PDF文档设置统一的访问口令，使用Python程序来处理会
非常的方便。
"""
import PyPDF2

reader = PyPDF2.PdfReader('XGBoost.pdf')
writer = PyPDF2.PdfWriter()

for page in reader.pages:
    writer.add_page(page)

writer.encrypt('foobared')

with open('temp.pdf', 'wb') as file_obj:
    writer.write(file_obj)

# %%
"""
批量添加水印
上面提到的PageObject对象还有一个名为mergePage的方法，可以两个 PDF 页面进行叠加，通过这个操作，我们很容易实现给PDF文件
添加水印的功能。例如要给上面的“XGBoost.pdf”文件添加一个水印，我们可以先准备好一个提供水印页面的 PDF 文件，然后将包含水印
的PageObject读取出来，然后再循环遍历“XGBoost.pdf”文件的每个页，获取到PageObject对象，然后通过mergePage方法实现水印
页和原始页的合并，代码如下所示。
"""
reader1 = PyPDF2.PdfReader('XGBoost.pdf')
reader2 = PyPDF2.PdfReader('watermark.pdf')
writer = PyPDF2.PdfWriter()
watermark_page = reader2.pages[0]

for page in reader1.pages:
    page.merge_page(watermark_page)
    writer.add_page(page)

with open('temp.pdf', 'wb') as file_obj:
    writer.write(file_obj)

# %%
"""
创建PDF文件
创建 PDF 文档需要三方库reportlab的支持，安装的方法如下所示。

pip install reportlab
"""

from reportlab.lib.pagesizes import A4
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.pdfgen import canvas

pdf_canvas = canvas.Canvas('resources/demo.pdf', pagesize=A4)
width, height = A4

# 绘图
image = canvas.ImageReader('resources/guido.jpg')
pdf_canvas.drawImage(image, 20, height - 395, 250, 375)

# 显示当前页
pdf_canvas.showPage()

# 注册字体文件
pdfmetrics.registerFont(TTFont('Font1', 'resources/fonts/Vera.ttf'))
pdfmetrics.registerFont(TTFont('Font2', 'resources/fonts/青呱石头体.ttf'))

# 写字
pdf_canvas.setFont('Font2', 40)
pdf_canvas.setFillColorRGB(0.9, 0.5, 0.3, 1)
pdf_canvas.drawString(width // 2 - 120, height // 2, '你好，世界！')
pdf_canvas.setFont('Font1', 40)
pdf_canvas.setFillColorRGB(0, 1, 0, 0.5)
pdf_canvas.rotate(18)
pdf_canvas.drawString(250, 250, 'hello, world!')

# 保存
pdf_canvas.save()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:525, in open_for_read.<locals>.open_for_read(name, mode)
#     524 try:
# --> 525     return open_for_read_by_name(name,mode)
#     526 except:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:463, in open_for_read_by_name(name, mode)
#     462 try:
# --> 463     return open(name,mode)
#     464 except IOError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resources/guido.jpg'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:532, in open_for_read.<locals>.open_for_read(name, mode)
#     531             raise ValueError('Attempted untrusted host access')
# --> 532     return BytesIO((datareader if name[:5].lower()=='data:' else rlUrlRead)(name))
#     533 except:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:478, in rlUrlRead(name, headers)
#     477 headers.setdefault('User-Agent','ReportLabAgent')
# --> 478 return urlopen(Request(name,headers=headers)).read()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:292, in Request.__init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     289 def __init__(self, url, data=None, headers={},
#     290              origin_req_host=None, unverifiable=False,
#     291              method=None):
# --> 292     self.full_url = url
#     293     self.headers = {}
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:318, in Request.full_url(self, url)
#     317 self._full_url, self.fragment = _splittag(self._full_url)
# --> 318 self._parse()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\urllib\request.py:347, in Request._parse(self)
#     346 if self.type is None:
# --> 347     raise ValueError("unknown url type: %r" % self.full_url)
#     348 self.host, self.selector = _splithost(rest)
#
# ValueError: unknown url type: 'resources/guido.jpg'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:645, in ImageReader.__init__(self, fileName, ident)
#     644     raise ValueError('imageReaderFlags values other than 0 are no longer supported; all images are interned now')
# --> 645 fp = open_for_read(fileName,'b')
#     646 if not isinstance(fp, BytesIO):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:534, in open_for_read.<locals>.open_for_read(name, mode)
#     533 except:
# --> 534     raise IOError('Cannot open resource "%s"' % name)
#
# OSError: Cannot open resource "resources/guido.jpg"
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 17
#      13 pdf_canvas = canvas.Canvas('resources/demo.pdf', pagesize=A4)
#      14 width, height = A4
#      15
#      16 # 绘图
# ---> 17 image = canvas.ImageReader('resources/guido.jpg')
#      18 pdf_canvas.drawImage(image, 20, height - 395, 250, 375)
#      19
#      20 # 显示当前页
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:657, in ImageReader.__init__(self, fileName, ident)
#     655         self.jpeg_fh = self._jpeg_fh
#     656 except:
# --> 657     annotateException('\nfileName=%r identity=%s'%(fileName,self.identity()))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:1178, in annotateException(msg, enc, postMsg, sep)
#    1176 '''add msg to the args of an existing exception'''
#    1177 t,v,b=sys.exc_info()
# -> 1178 rl_reraise(t,t(sep.join((_ for _ in (msg,str(v),postMsg) if _))),b)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:138, in rl_reraise(t, v, b)
#     136 def rl_reraise(t, v, b=None):
#     137     if v.__traceback__ is not b:
# --> 138         raise v.with_traceback(b)
#     139     raise v
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:645, in ImageReader.__init__(self, fileName, ident)
#     643 if imageReaderFlags != 0:
#     644     raise ValueError('imageReaderFlags values other than 0 are no longer supported; all images are interned now')
# --> 645 fp = open_for_read(fileName,'b')
#     646 if not isinstance(fp, BytesIO):
#     647     tfp, fp = fp, BytesIO(fp.read())
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\reportlab\lib\utils.py:534, in open_for_read.<locals>.open_for_read(name, mode)
#     532     return BytesIO((datareader if name[:5].lower()=='data:' else rlUrlRead)(name))
#     533 except:
# --> 534     raise IOError('Cannot open resource "%s"' % name)
#
# OSError:
# fileName='resources/guido.jpg' identity=[ImageReader@0x1269c78d040 filename='resources/guido.jpg'] Cannot open resource "resources/guido.jpg"
